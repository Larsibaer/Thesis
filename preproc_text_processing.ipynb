# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import re
from wordcloud import WordCloud
import nltk
from nltk.corpus import stopwords

from ydata_profiling import ProfileReport

# %matplotlib inline

pd.options.mode.chained_assignment = None  # default='warn'

# your code that triggers the warning goes here

pd.options.mode.chained_assignment = 'warn'  # set it back to the default value

# %%
 
# Specifying data types for columns while reading a CSV file
dtype_dict = {
    "number": "str",
    "closed": "str", 
    "case": "str",
    "description": "str",
    "case_type": "category",
    "due_date": "str", 
    "first_response_time": "str", 
    "opened": "str",  
    "account": "category",
    "contact": "category",
    "created_by": "category",
    "business_service": "category",
    "business_service_activity": "category",
    "assigned_to": "category",
    "assignment_group": "category",
    "auto_close": "category",
    "time_worked": "float",
    "reassignment_count": "int",
    "impact": "category",
    "priority": "category",
    "urgency": "category",
    "escalation": "category",
    "comments": "str",
    "case_cause": "category",
    "cause": "str",
    "close_notes": "str",
    "resolution_code": "category",
    "problem": "category",
    "business_percentage": "float",
    "sla_has_breached": "category",
    "duration": "float",
    "openedToClosed": "float",
    "created_by_group": "category"
}

# read csv file into dataframe
df = pd.read_csv('Data/data.csv', dtype = dtype_dict)

# concat short_description and description columns. Handle NaN values
df['short_description'] = df['short_description'].fillna('')
df['description'] = df['description'].fillna('')
df['description'] = df['short_description'].str.cat(df['description'], sep =" ")

# print shape of dataframe 
print(df.shape)
print(df.columns)
display(df)
# Out:
# (11746, 20)
# Index(['number', 'account', 'created_by_group', 'business_service',
#        'assignment_group', 'impact', 'priority', 'urgency', 'sla_has_breached',
#        'case_cause', 'resolution_code', 'opened', 'closed', 'time_worked',
#        'openedToClosed', 'business_percentage', 'description',
#        'short_description', 'cause', 'close_notes'],
#       dtype='object')
#           number                               account created_by_group  \
# 0      CS0011381              Saphir Group Networks AG            Unico
# 1      CS0011690             GASSMANN Rechtsanwälte AG            Unico
# 2      CS0011797                             Siloah AG            Unico
# 3      CS0011896                         Interhydro AG            Unico
# 4      CS0012000  Verband Regionaler SD Münchenbuchsee             User
# ...          ...                                   ...              ...
# 11741  CS0076818                             Siloah AG            Unico
# 11742  CS0076821                             Siloah AG            Unico
# 11743  CS0076822                        PB Swiss Tools            Unico
# 11744  CS0076849                             Siloah AG            Unico
# 11745  CS0076852                             Siloah AG            Unico
#
#                                         business_service  \
# 0                                      Managed Workplace
# 1                                         Hosted Desktop
# 2                                         Hosted Desktop
# 3         No Business Service - only best effort service
# 4         No Business Service - only best effort service
# ...                                                  ...
# 11741  Anmeldeprobleme auf Hosted Desktop beheben (Pa...
# 11742       Übrige Störungen und Anfragen Hosted Desktop
# 11743                Session freigeben in Hosted Desktop
# 11744  Applikationsstörung (Standard Applikation) beh...
# 11745  Applikationsstörung (Standard Applikation) beh...
#
#              assignment_group      impact      priority     urgency  \
# 0      Service Desk 1st Level     3 - Low       4 - Low  2 - Medium
# 1      Service Desk 1st Level     3 - Low  5 - Planning     3 - Low
# 2      Service Desk 1st Level     3 - Low  3 - Moderate    1 - High
# 3               IT Operations     3 - Low  5 - Planning     3 - Low
# 4      Service Desk 2nd Level     3 - Low       4 - Low  2 - Medium
# ...                       ...         ...           ...         ...
# 11741          Squad Platform  2 - Medium  3 - Moderate  2 - Medium
# 11742    Vorortsupport Siloah  2 - Medium  3 - Moderate  2 - Medium
# 11743  Service Desk 1st Level  2 - Medium  3 - Moderate  2 - Medium
# 11744  Service Desk 1st Level  2 - Medium  3 - Moderate  2 - Medium
# 11745  Service Desk 1st Level  2 - Medium  3 - Moderate  2 - Medium
#
#       sla_has_breached                                         case_cause  \
# 0                 TRUE  Unico - Product-error in software or hardware ...
# 1                 TRUE                      Customer - incorrect handling
# 2                 TRUE                      Customer - incorrect handling
# 3                 TRUE  Customer - Third party (e.g. Internetprovider,...
# 4                 TRUE  Customer - Third party (e.g. Internetprovider,...
# ...                ...                                                ...
# 11741            FALSE  Customer - Product-error in software or hardwa...
# 11742            FALSE  Unico - Product-error in software or hardware ...
# 11743            FALSE  Unico - Product-error in software or hardware ...
# 11744            FALSE  Unico - incorrect handling, incorrect decision...
# 11745            FALSE                      Customer - incorrect handling
#
#                                    resolution_code               opened  \
# 0      Solved – Fixed by Support/Guidance provided  2020-01-09 15:32:00
# 1      Solved – Fixed by Support/Guidance provided  2020-01-16 08:19:12
# 2      Solved – Fixed by Support/Guidance provided  2020-01-20 12:26:23
# 3                                  Voided/Canceled  2020-01-21 18:18:46
# 4                      Inconclusive – Out of scope  2020-01-23 17:09:10
# ...                                            ...                  ...
# 11741  Solved – Fixed by Support/Guidance provided  2024-02-10 07:48:59
# 11742  Solved – Fixed by Support/Guidance provided  2024-02-12 05:57:13
# 11743  Solved – Fixed by Support/Guidance provided  2024-02-12 06:06:02
# 11744  Solved – Fixed by Support/Guidance provided  2024-02-12 13:08:42
# 11745  Solved – Fixed by Support/Guidance provided  2024-02-12 13:58:03
#
#                     closed  time_worked  openedToClosed  business_percentage  \
# 0      2020-05-18 19:10:46        360.0      804.900972               105.62
# 1      2020-08-19 10:30:06        360.0      804.900972               135.01
# 2      2020-05-18 19:10:48        360.0      804.900972               135.01
# 3      2020-06-23 14:51:27        900.0      804.900972               135.01
# 4      2020-05-18 19:10:49        360.0      804.900972               135.01
# ...                    ...          ...             ...                  ...
# 11741  2024-02-19 22:30:09       2700.0      230.686111                 0.03
# 11742  2024-02-19 22:30:10       3240.0      184.549167                 4.59
# 11743  2024-02-19 22:30:10        900.0      184.402222                 1.80
# 11744  2024-02-19 22:30:14        720.0      177.358889                 0.04
# 11745  2024-02-19 22:30:14       1080.0      176.536389                 0.04
#
#                                              description  \
# 0      Herr Steiner - HP Notebook Docking Probleme Ha...
# 1      E-Mail-Archive TAB im Outlook einrichten (User...
# 2      Performance am Standort Neuhaus sehr langsam W...
# 3      Cloudberry Backup: HV002-monthly failed 'Micro...
# 4      Pay Pen funktioniert nicht im Programm SAGE Gu...
# ...                                                  ...
# 11741  Luana Filippi, Anmeldung VDI nicht möglich Fra...
# 11742  Nagaratnam Thavaraja - drucken Drucker "prt-C1...
# 11743  Parthiban Nathan - Desktop VDI kann nicht mehr...
# 11744  Christian Kunz, Fehlender Archiv ordner Nach d...
# 11745  Fabian Nyffenegger, MS Teams, MS Teams fehlt i...
#
#                                        short_description  \
# 0            Herr Steiner - HP Notebook Docking Probleme
# 1      E-Mail-Archive TAB im Outlook einrichten (User...
# 2           Performance am Standort Neuhaus sehr langsam
# 3                Cloudberry Backup: HV002-monthly failed
# 4            Pay Pen funktioniert nicht im Programm SAGE
# ...                                                  ...
# 11741         Luana Filippi, Anmeldung VDI nicht möglich
# 11742  Nagaratnam Thavaraja - drucken Drucker "prt-C1...
# 11743  Parthiban Nathan - Desktop VDI kann nicht mehr...
# 11744            Christian Kunz, Fehlender Archiv ordner
# 11745  Fabian Nyffenegger, MS Teams, MS Teams fehlt i...
#
#                                                    cause  \
# 0      Workaround mit Windows Energy Einstellungen (K...
# 1                                                    NaN
# 2                                                    NaN
# 3                                     Wechsel auf Altaro
# 4      Sage empfiehlt direkt mit dem Hersteller des P...
# ...                                                  ...
# 11741                 Probleme mit Citrix Workspace App.
# 11742                                          unbekannt
# 11743  blockierte Session auf dem Server Staus "Loggi...
# 11744  Wurde beim vorderen Case nicht wieder verknüpf...
# 11745                           Teams Gruppe hat gefehlt
#
#                                              close_notes
# 0      Workaround mit Windows Energy Einstellungen (K...
# 1                      Archiv wie gewünscht konfiguriert
# 2      gemäss Telefon mit Sandro Borer ist die Perfor...
# 3                                     Wechsel auf Altaro
# 4      Guten Tag Frau Bär\r\r\n\r\r\nVielen Dank für ...
# ...                                                  ...
# 11741  Workaround-Lösung implementiert. Login via Bro...
# 11742  neustart des Druckers und überprüfung der Netz...
# 11743  Session auf dem Server geschlossen - danach ka...
# 11744  Archivorder aus dem Laufwerk H:\Outlook ordner...
# 11745                           Teams Gruppe zugeordnet.
#
# [11746 rows x 20 columns]

# %%
# display Short Description (case), Description, Cause and close_notes
df_text = df[['number', 'description', 'cause', 'close_notes']]

# preprocess df_text columns 

display(df_text)
# Out:
#           number                                        description  \
# 0      CS0011381  Herr Steiner - HP Notebook Docking Probleme Ha...
# 1      CS0011690  E-Mail-Archive TAB im Outlook einrichten (User...
# 2      CS0011797  Performance am Standort Neuhaus sehr langsam W...
# 3      CS0011896  Cloudberry Backup: HV002-monthly failed 'Micro...
# 4      CS0012000  Pay Pen funktioniert nicht im Programm SAGE Gu...
# ...          ...                                                ...
# 11741  CS0076818  Luana Filippi, Anmeldung VDI nicht möglich Fra...
# 11742  CS0076821  Nagaratnam Thavaraja - drucken Drucker "prt-C1...
# 11743  CS0076822  Parthiban Nathan - Desktop VDI kann nicht mehr...
# 11744  CS0076849  Christian Kunz, Fehlender Archiv ordner Nach d...
# 11745  CS0076852  Fabian Nyffenegger, MS Teams, MS Teams fehlt i...
#
#                                                    cause  \
# 0      Workaround mit Windows Energy Einstellungen (K...
# 1                                                    NaN
# 2                                                    NaN
# 3                                     Wechsel auf Altaro
# 4      Sage empfiehlt direkt mit dem Hersteller des P...
# ...                                                  ...
# 11741                 Probleme mit Citrix Workspace App.
# 11742                                          unbekannt
# 11743  blockierte Session auf dem Server Staus "Loggi...
# 11744  Wurde beim vorderen Case nicht wieder verknüpf...
# 11745                           Teams Gruppe hat gefehlt
#
#                                              close_notes
# 0      Workaround mit Windows Energy Einstellungen (K...
# 1                      Archiv wie gewünscht konfiguriert
# 2      gemäss Telefon mit Sandro Borer ist die Perfor...
# 3                                     Wechsel auf Altaro
# 4      Guten Tag Frau Bär\r\r\n\r\r\nVielen Dank für ...
# ...                                                  ...
# 11741  Workaround-Lösung implementiert. Login via Bro...
# 11742  neustart des Druckers und überprüfung der Netz...
# 11743  Session auf dem Server geschlossen - danach ka...
# 11744  Archivorder aus dem Laufwerk H:\Outlook ordner...
# 11745                           Teams Gruppe zugeordnet.
#
# [11746 rows x 4 columns]

# %%
def process_captions(data, column):
    data[column] = data[column].apply(lambda x: x.replace('\n', ' '))
    data[column] = data[column].apply(lambda x: x.replace('-', ' '))
    data[column] = data[column].apply(lambda x: x.lower())
    data[column] = data[column].apply(lambda x: re.sub('[^a-zA-ZäÄöÖüÜ\s]', ' ', x))
    return data[column]

# change datatype of columns to string
df_text['description'] = df_text['description'].astype(str).copy()
df_text['cause'] = df_text['cause'].astype(str).copy()
df_text['close_notes'] = df_text['close_notes'].astype(str).copy()

df_text['description'] = process_captions(df_text, 'description').copy()
df_text['cause'] = process_captions(df_text, 'cause').copy()
df_text['close_notes'] = process_captions(df_text, 'close_notes').copy()

display(df_text)
# Out:
# C:\Users\Student\AppData\Local\Temp\ipykernel_24244\4016132248.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_text['description'] = df_text['description'].astype(str).copy()
# C:\Users\Student\AppData\Local\Temp\ipykernel_24244\4016132248.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_text['cause'] = df_text['cause'].astype(str).copy()
# C:\Users\Student\AppData\Local\Temp\ipykernel_24244\4016132248.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_text['close_notes'] = df_text['close_notes'].astype(str).copy()
# C:\Users\Student\AppData\Local\Temp\ipykernel_24244\4016132248.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data[column].apply(lambda x: x.replace('\n', ' '))
# C:\Users\Student\AppData\Local\Temp\ipykernel_24244\4016132248.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data[column].apply(lambda x: x.replace('-', ' '))
# C:\Users\Student\AppData\Local\Temp\ipykernel_24244\4016132248.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data[column].apply(lambda x: x.lower())
# C:\Users\Student\AppData\Local\Temp\ipykernel_24244\4016132248.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = data[column].apply(lambda x: re.sub('[^a-zA-ZäÄöÖüÜ\s]', ' ', x))
# C:\Users\Student\AppData\Local\Temp\ipykernel_24244\4016132248.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_text['description'] = process_captions(df_text, 'description').copy()
# C:\Users\Student\AppData\Local\Temp\ipykernel_24244\4016132248.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_text['cause'] = process_captions(df_text, 'cause').copy()
# C:\Users\Student\AppData\Local\Temp\ipykernel_24244\4016132248.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_text['close_notes'] = process_captions(df_text, 'close_notes').copy()
#           number                                        description  \
# 0      CS0011381  herr steiner   hp notebook docking probleme ha...
# 1      CS0011690  e mail archive tab im outlook einrichten  user...
# 2      CS0011797  performance am standort neuhaus sehr langsam w...
# 3      CS0011896  cloudberry backup  hv    monthly failed  micro...
# 4      CS0012000  pay pen funktioniert nicht im programm sage gu...
# ...          ...                                                ...
# 11741  CS0076818  luana filippi  anmeldung vdi nicht möglich fra...
# 11742  CS0076821  nagaratnam thavaraja   drucken drucker  prt c ...
# 11743  CS0076822  parthiban nathan   desktop vdi kann nicht mehr...
# 11744  CS0076849  christian kunz  fehlender archiv ordner nach d...
# 11745  CS0076852  fabian nyffenegger  ms teams  ms teams fehlt i...
#
#                                                    cause  \
# 0      workaround mit windows energy einstellungen  k...
# 1                                                    nan
# 2                                                    nan
# 3                                     wechsel auf altaro
# 4      sage empfiehlt direkt mit dem hersteller des p...
# ...                                                  ...
# 11741                 probleme mit citrix workspace app
# 11742                                          unbekannt
# 11743  blockierte session auf dem server staus  loggi...
# 11744  wurde beim vorderen case nicht wieder verknüpf...
# 11745                           teams gruppe hat gefehlt
#
#                                              close_notes
# 0      workaround mit windows energy einstellungen  k...
# 1                      archiv wie gewünscht konfiguriert
# 2      gemäss telefon mit sandro borer ist die perfor...
# 3                                     wechsel auf altaro
# 4      guten tag frau bär\r\r \r\r vielen dank für ih...
# ...                                                  ...
# 11741  workaround lösung implementiert  login via bro...
# 11742  neustart des druckers und überprüfung der netz...
# 11743  session auf dem server geschlossen   danach ka...
# 11744  archivorder aus dem laufwerk h  outlook ordner...
# 11745                           teams gruppe zugeordnet
#
# [11746 rows x 4 columns]

# %%
import requests

stopwords = requests.get("https://raw.githubusercontent.com/stopwords-iso/stopwords-de/master/stopwords-de.txt").text.split("\n")
# Add common words to stopwords. Added dynamically after checking the most common words
stopwords.extend(["nan", "frau", "herr", "name", "ch", "bitte", "und", "die", "das", "ist", "zu", "den", "der", "es", "ein", "sie", 
                        "nicht", "von", "mit", "dem", "sich", "auf", "für", "an", "sind", "des", "wird", "dass", "im", "auch", "als", 
                        "an", "nach", "wie", "aber", "aus", "bei", "durch", "hat", "man", "noch", "einem", "über", "einer", "um", "am", 
                        "ohne", "zwischen", "so", "nur", "zum", "kann", "vor", "dieser", "bis", "habe", "wenn", "sein", "wird", "wurde", 
                        "können", "gegen", "dann", "müssen", "diese", "weil", "welche", "oder", "zwei", "eines", "mehr", "Jahre", "wieder", 
                        "keine", "hallo", "grüsse", "gruss", "vielen", "besten", "dank", "guten", "morgen", "tag", "freundlich", "liebe", 
                        "lieber", "sehr geehrte", "geehrter", "geehrte", "hi", "de", "guten tag", "beste", "herzliche", "liebe grüße", "vielen dank", 
                        "besten dank", "freundliche", "grüße", "danke", "siehe", "tel", "mail", "mehr", "à", "vous", "la", "le", "e", "en", "et", "mon", "je", 
                        "les", "pas", "que", "a", "c", "e", "compt", "est", "une", "il", "the", "at"])
from sklearn.feature_extraction.text import TfidfVectorizer

# Remove all characters after "Freundliche Grüsse" or "Beste Grüsse"
df_text['description'] = df_text['description'].apply(lambda x: x.split('freundliche gr')[0])
df_text['description'] = df_text['description'].apply(lambda x: x.split('beste gr')[0])
df_text['description'] = df_text['description'].apply(lambda x: x.split('vielen dank')[0])
df_text['description'] = df_text['description'].apply(lambda x: x.split('von:')[0])

# Create empty df to store the top 50 words for each column
top_50_words = pd.DataFrame()

for column in df_text.columns[1:]:
    tfidf = TfidfVectorizer(stop_words=stopwords)
    text = tfidf.fit_transform(df_text[column])

    VectorizedText = pd.DataFrame(text.toarray(), columns=tfidf.get_feature_names_out())
    # Add to all columns the column name
    VectorizedText.columns = [column + "_" + col for col in VectorizedText.columns]
    column_sums = VectorizedText.sum(axis=0).sort_values(ascending=False)

    # Select the names of the top 50 columns with the highest sums
    top_50_columns = column_sums.head(15).index
    top_50_words[column] = top_50_columns

    # Subset the original DataFrame to keep only these top 50 columns
    minimized_df = VectorizedText[top_50_columns]

    # Add from the original df the column number to the minimized_df at first position
    minimized_df.insert(0, 'number', df_text['number'])

    # save minimized_df to csv
    minimized_df.to_csv('Data/VectorizedText_' + column + '.csv', index=False)
# Out:
# C:\Users\Student\AppData\Local\Temp\ipykernel_24244\2359770970.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_text['description'] = df_text['description'].apply(lambda x: x.split('freundliche gr')[0])
# C:\Users\Student\AppData\Local\Temp\ipykernel_24244\2359770970.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_text['description'] = df_text['description'].apply(lambda x: x.split('beste gr')[0])
# C:\Users\Student\AppData\Local\Temp\ipykernel_24244\2359770970.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_text['description'] = df_text['description'].apply(lambda x: x.split('vielen dank')[0])
# C:\Users\Student\AppData\Local\Temp\ipykernel_24244\2359770970.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_text['description'] = df_text['description'].apply(lambda x: x.split('von:')[0])

# %%
# For topic Modelling
top_50_words = pd.DataFrame()
for column in df_text.columns[1:]:
    tfidf = TfidfVectorizer(stop_words=stopwords)
    text = tfidf.fit_transform(df_text[column])

    VectorizedText = pd.DataFrame(text.toarray(), columns=tfidf.get_feature_names_out())
    # Add to all columns the column name
    # VectorizedText.columns = [column + "_" + col for col in VectorizedText.columns]
    column_sums = VectorizedText.sum(axis=0).sort_values(ascending=False)

    # Select the names of the top 50 columns with the highest sums
    top_50_columns = column_sums.head(150).index
    top_50_words[column] = top_50_columns

    # only remain words in df_text that are in top_50_words
    df_text2 = df_text[['number', column]].copy()
    df_text2[column] = df_text2[column].apply(lambda x: ' '.join([word for word in x.split() if word in top_50_words['description'].values]))

    # save minimized_df to csv
    df_text2.to_csv('Data/TopicModel_VectorizedText_' + column + '.csv', index=False)
